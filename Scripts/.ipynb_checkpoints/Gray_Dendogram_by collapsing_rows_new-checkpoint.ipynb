# %%
import os
import sys
import numpy as np
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import dendrogram
from sklearn.datasets import load_iris, load_digits
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
import pandas as pd
import matplotlib.pyplot as plt
import plotnine as gg
from sklearn.cluster import AgglomerativeClustering
import sklearn.metrics as sm
import seaborn

# %%
os.getcwd()
# Out:
# '/Users/habbasi/Documents/Broad/Broad_collaborative_projects /Broad_profiling_projects/050919_Nathianel_Gray/Scripts'

# %%
path = '/Users/habbasi/Desktop/2018_11_20_Batch1'
file1 = os.path.join(path, 'C-7210-01-CMP-008-gray_collapsed.csv')

# Platemap 
path = '/Users/habbasi/Desktop/2018_11_20_Batch1'
file2 = os.path.join(path, 'Nathaniel_Gray_platemap.csv')


data1 = pd.read_csv(file1)
data2 = pd.read_csv(file2)


#Merging of dataframes (Platemap with compound information + old data)
#data = data2.merge(data1, on = ['Metadata_broad_sample'])

data = pd.merge(data1, data2, on=['Metadata_broad_sample'], how='inner')
data.head()

#data.to_csv("/Users/habbasi/Desktop/2018_11_20_Batch1/C-7210-01-CMP-008-gray_collapsed_new1.csv", index=False)
data.head()
metacol = data.columns.str.contains('Metadata')
var = data.loc[:, ~metacol]
compound = pd.DataFrame(data[['Metadata_compound_name', 'Metadata_Annotation']])
df = compound.merge(var, left_index=True, right_index=True)
df.head()
# Out:
#   Metadata_compound_name Metadata_Annotation  Cells_AreaShape_Area  \
# 0                   DMSO             control             -0.338651
# 1                   DMSO             control              0.002656
# 2                   DMSO             control             -0.078401
# 3                   DMSO             control             -0.292199
# 4                   DMSO             control             -0.486082
#
#    Cells_AreaShape_Compactness  Cells_AreaShape_Eccentricity  \
# 0                    -0.358403                     -0.327824
# 1                     0.223358                      0.243922
# 2                     1.031104                      0.918579
# 3                     1.091156                      1.445546
# 4                     1.520651                      1.348605
#
#    Cells_AreaShape_Extent  Cells_AreaShape_FormFactor  \
# 0                0.090855                    0.331456
# 1               -0.146758                    0.235445
# 2               -1.040527                   -0.740076
# 3               -1.202122                    0.427984
# 4               -1.000145                    0.192637
#
#    Cells_AreaShape_Solidity  Cells_AreaShape_Zernike_0_0  \
# 0                  0.007196                     0.334137
# 1                 -0.008030                    -0.152354
# 2                 -1.120205                    -0.956084
# 3                 -0.405610                    -0.896888
# 4                 -0.939495                    -0.862107
#
#    Cells_AreaShape_Zernike_2_0                ...                 \
# 0                     0.377472                ...
# 1                     0.345686                ...
# 2                     0.127276                ...
# 3                    -0.446857                ...
# 4                    -1.070563                ...
#
#    Nuclei_Texture_SumAverage_Mito_5_0  Nuclei_Texture_SumAverage_RNA_20_0  \
# 0                            5.164938                            2.455603
# 1                            5.224594                            2.466235
# 2                            4.433582                            1.607650
# 3                            4.790513                            2.049889
# 4                            4.415261                            1.759330
#
#    Nuclei_Texture_SumEntropy_DNA_10_0  Nuclei_Texture_SumEntropy_DNA_20_0  \
# 0                            0.526889                           -0.374890
# 1                            1.039002                            0.359449
# 2                           -0.528519                           -0.840525
# 3                            1.129831                            0.124433
# 4                           -0.679289                           -1.082227
#
#    Nuclei_Texture_SumEntropy_DNA_5_0  Nuclei_Texture_SumEntropy_RNA_5_0  \
# 0                           0.228141                           1.703870
# 1                           0.353371                           1.746358
# 2                          -0.571717                           1.007865
# 3                           0.759763                           1.730682
# 4                          -0.505341                           1.561501
#
#    Nuclei_Texture_SumVariance_DNA_20_0  Nuclei_Texture_Variance_ER_20_0  \
# 0                            -0.293441                        -0.750370
# 1                             0.363410                        -0.399584
# 2                            -0.962445                        -1.555760
# 3                             0.057532                        -0.299879
# 4                            -1.312822                        -0.120841
#
#    Nuclei_Texture_Variance_Mito_20_0  Nuclei_Texture_Variance_RNA_10_0
# 0                          -1.067705                          2.443629
# 1                          -0.570497                          2.934718
# 2                          -1.393898                          2.521685
# 3                          -0.390767                          2.378503
# 4                          -0.694946                          2.649963
#
# [5 rows x 600 columns]

# %%
# compounds names are converted into index column using groupby function and reset it back
# df_merge = df_merge.rename_axis('Metadata_compound_name').reset_index()
# df_merge.head()

# %%
# Aggregating mean profiles per Metadata_Broad_sample
df_merge = df.groupby('Metadata_compound_name').mean()
df_merge.head()

sample_var = df_merge.columns.str.contains('Metadata')
var_selected = df_merge.loc[:, ~sample_var]
var_selected.head()
# Out:
#                         Cells_AreaShape_Area  Cells_AreaShape_Compactness  \
# Metadata_compound_name
# AX15836                            -0.775979                    -0.244262
# BJP-06-005-3                       -0.576870                    -0.253715
# BJP-06-115-3                       -0.609039                    -0.322537
# BSJ-03-136                          3.906117                     3.560020
# BSJ-04-030                          2.110605                     0.590785
#
#                         Cells_AreaShape_Eccentricity  Cells_AreaShape_Extent  \
# Metadata_compound_name
# AX15836                                    -0.386021                0.173087
# BJP-06-005-3                               -0.379721                0.229889
# BJP-06-115-3                               -0.458257                0.208973
# BSJ-03-136                                  3.079834               -3.070611
# BSJ-04-030                                  0.265076               -1.087407
#
#                         Cells_AreaShape_FormFactor  Cells_AreaShape_Solidity  \
# Metadata_compound_name
# AX15836                                   0.350243                  0.033650
# BJP-06-005-3                              0.325399                  0.144148
# BJP-06-115-3                              0.212805                  0.046103
# BSJ-03-136                               -1.253681                 -0.130163
# BSJ-04-030                               -1.176394                 -0.012309
#
#                         Cells_AreaShape_Zernike_0_0  \
# Metadata_compound_name
# AX15836                                    0.594214
# BJP-06-005-3                               0.463031
# BJP-06-115-3                               0.515692
# BSJ-03-136                                -3.463964
# BSJ-04-030                                -1.196037
#
#                         Cells_AreaShape_Zernike_2_0  \
# Metadata_compound_name
# AX15836                                    0.140865
# BJP-06-005-3                               0.175006
# BJP-06-115-3                               0.246543
# BSJ-03-136                                -1.864802
# BSJ-04-030                                 0.169989
#
#                         Cells_AreaShape_Zernike_3_1  \
# Metadata_compound_name
# AX15836                                   -0.306743
# BJP-06-005-3                              -0.219663
# BJP-06-115-3                              -0.257748
# BSJ-03-136                                 2.466615
# BSJ-04-030                                -0.026851
#
#                         Cells_AreaShape_Zernike_3_3  \
# Metadata_compound_name
# AX15836                                    0.639600
# BJP-06-005-3                               0.507701
# BJP-06-115-3                               0.415530
# BSJ-03-136                                -1.262589
# BSJ-04-030                                -1.238263
#
#                                       ...                 \
# Metadata_compound_name                ...
# AX15836                               ...
# BJP-06-005-3                          ...
# BJP-06-115-3                          ...
# BSJ-03-136                            ...
# BSJ-04-030                            ...
#
#                         Nuclei_Texture_SumAverage_Mito_5_0  \
# Metadata_compound_name
# AX15836                                           0.557308
# BJP-06-005-3                                      0.507972
# BJP-06-115-3                                      0.093719
# BSJ-03-136                                        1.249316
# BSJ-04-030                                       -0.045753
#
#                         Nuclei_Texture_SumAverage_RNA_20_0  \
# Metadata_compound_name
# AX15836                                           0.140026
# BJP-06-005-3                                     -0.054632
# BJP-06-115-3                                     -0.282037
# BSJ-03-136                                        0.276708
# BSJ-04-030                                       -0.715485
#
#                         Nuclei_Texture_SumEntropy_DNA_10_0  \
# Metadata_compound_name
# AX15836                                           0.273171
# BJP-06-005-3                                      0.173438
# BJP-06-115-3                                     -0.084258
# BSJ-03-136                                        0.548774
# BSJ-04-030                                       -0.229877
#
#                         Nuclei_Texture_SumEntropy_DNA_20_0  \
# Metadata_compound_name
# AX15836                                          -0.182929
# BJP-06-005-3                                     -0.105549
# BJP-06-115-3                                     -0.320325
# BSJ-03-136                                        0.763211
# BSJ-04-030                                        0.171510
#
#                         Nuclei_Texture_SumEntropy_DNA_5_0  \
# Metadata_compound_name
# AX15836                                          0.374104
# BJP-06-005-3                                     0.263737
# BJP-06-115-3                                     0.027365
# BSJ-03-136                                      -0.000387
# BSJ-04-030                                      -0.444318
#
#                         Nuclei_Texture_SumEntropy_RNA_5_0  \
# Metadata_compound_name
# AX15836                                          0.542760
# BJP-06-005-3                                     0.344356
# BJP-06-115-3                                     0.191586
# BSJ-03-136                                      -0.050530
# BSJ-04-030                                      -0.730512
#
#                         Nuclei_Texture_SumVariance_DNA_20_0  \
# Metadata_compound_name
# AX15836                                           -0.252515
# BJP-06-005-3                                      -0.226448
# BJP-06-115-3                                      -0.475140
# BSJ-03-136                                         1.824343
# BSJ-04-030                                         0.678970
#
#                         Nuclei_Texture_Variance_ER_20_0  \
# Metadata_compound_name
# AX15836                                        0.048167
# BJP-06-005-3                                  -0.407271
# BJP-06-115-3                                  -0.439627
# BSJ-03-136                                     0.644147
# BSJ-04-030                                     0.637961
#
#                         Nuclei_Texture_Variance_Mito_20_0  \
# Metadata_compound_name
# AX15836                                          0.057386
# BJP-06-005-3                                    -0.100908
# BJP-06-115-3                                    -0.220809
# BSJ-03-136                                       0.633125
# BSJ-04-030                                       0.000906
#
#                         Nuclei_Texture_Variance_RNA_10_0
# Metadata_compound_name
# AX15836                                         0.370566
# BJP-06-005-3                                    0.221862
# BJP-06-115-3                                    0.022798
# BSJ-03-136                                     -0.225603
# BSJ-04-030                                     -0.333072
#
# [5 rows x 598 columns]

# %% [markdown]
# # Data Parsing

# %%
filter_A549 = (data.Metadata_Plate == 'BR00100032') | (data.Metadata_cell_line == 'A549')
filter_U2oS  = (data.Metadata_Plate == 'BR00100037') | (data.Metadata_cell_line == 'U2oS')

data_A549 = data[filter_A549]
data_U2oS = data[filter_U2oS]

data_U2oS.head()

metacol_A549 = data_A549.columns.str.contains('Metadata')
metacol_U2oS = data_U2oS.columns.str.contains('Metadata')

var_A549 = data_A549.loc[:, ~metacol_A549]
compound_A549 = pd.DataFrame(data_A549[['Metadata_compound_name', 'Metadata_Annotation']])

var_U2oS = data_U2oS.loc[:, ~metacol_U2oS]
compound_U2oS = pd.DataFrame(data_U2oS[['Metadata_compound_name', 'Metadata_Annotation']])

df_A549 = compound_A549.merge(var_A549, left_index=True, right_index=True)
df_A549_merge = df_A549.groupby('Metadata_compound_name').mean()

df_U2oS = compound_U2oS.merge(var_U2oS, left_index=True, right_index=True)
df_U2oS_merge = df_U2oS.groupby('Metadata_compound_name').mean()

df_U2oS_merge.head()
# Out:
#                         Cells_AreaShape_Area  Cells_AreaShape_Compactness  \
# Metadata_compound_name
# AX15836                            -0.880702                    -0.667770
# BJP-06-005-3                       -0.618417                    -0.475001
# BJP-06-115-3                       -0.644676                    -0.574528
# BSJ-03-136                          2.827595                     3.102461
# BSJ-04-030                          2.068861                     1.919291
#
#                         Cells_AreaShape_Eccentricity  Cells_AreaShape_Extent  \
# Metadata_compound_name
# AX15836                                    -0.743821                0.585738
# BJP-06-005-3                               -0.475690                0.348810
# BJP-06-115-3                               -0.628840                0.424655
# BSJ-03-136                                  1.419406               -4.843746
# BSJ-04-030                                  1.081609               -2.976643
#
#                         Cells_AreaShape_FormFactor  Cells_AreaShape_Solidity  \
# Metadata_compound_name
# AX15836                                   0.207029                  0.213651
# BJP-06-005-3                              0.164993                  0.217936
# BJP-06-115-3                              0.054407                  0.136659
# BSJ-03-136                               -0.772142                 -1.285012
# BSJ-04-030                               -0.343839                 -0.496305
#
#                         Cells_AreaShape_Zernike_0_0  \
# Metadata_compound_name
# AX15836                                    0.723277
# BJP-06-005-3                               0.393621
# BJP-06-115-3                               0.520802
# BSJ-03-136                                -3.138325
# BSJ-04-030                                -2.187166
#
#                         Cells_AreaShape_Zernike_2_0  \
# Metadata_compound_name
# AX15836                                    0.677655
# BJP-06-005-3                               0.494344
# BJP-06-115-3                               0.612779
# BSJ-03-136                                -2.498963
# BSJ-04-030                                -1.515240
#
#                         Cells_AreaShape_Zernike_3_1  \
# Metadata_compound_name
# AX15836                                   -0.678137
# BJP-06-005-3                              -0.423960
# BJP-06-115-3                              -0.534148
# BSJ-03-136                                 1.728469
# BSJ-04-030                                 1.259169
#
#                         Cells_AreaShape_Zernike_3_3  \
# Metadata_compound_name
# AX15836                                    0.632492
# BJP-06-005-3                               0.410585
# BJP-06-115-3                               0.230595
# BSJ-03-136                                -0.725627
# BSJ-04-030                                -0.743113
#
#                                       ...                 \
# Metadata_compound_name                ...
# AX15836                               ...
# BJP-06-005-3                          ...
# BJP-06-115-3                          ...
# BSJ-03-136                            ...
# BSJ-04-030                            ...
#
#                         Nuclei_Texture_SumAverage_Mito_5_0  \
# Metadata_compound_name
# AX15836                                           0.382654
# BJP-06-005-3                                      1.031989
# BJP-06-115-3                                      0.031406
# BSJ-03-136                                       -0.314659
# BSJ-04-030                                       -0.144547
#
#                         Nuclei_Texture_SumAverage_RNA_20_0  \
# Metadata_compound_name
# AX15836                                           0.388627
# BJP-06-005-3                                      0.121367
# BJP-06-115-3                                     -0.238080
# BSJ-03-136                                       -0.013041
# BSJ-04-030                                       -0.268965
#
#                         Nuclei_Texture_SumEntropy_DNA_10_0  \
# Metadata_compound_name
# AX15836                                           0.016930
# BJP-06-005-3                                     -0.088522
# BJP-06-115-3                                     -0.392944
# BSJ-03-136                                        0.557911
# BSJ-04-030                                        0.256724
#
#                         Nuclei_Texture_SumEntropy_DNA_20_0  \
# Metadata_compound_name
# AX15836                                          -0.031719
# BJP-06-005-3                                     -0.072619
# BJP-06-115-3                                     -0.373796
# BSJ-03-136                                        0.463807
# BSJ-04-030                                        0.231348
#
#                         Nuclei_Texture_SumEntropy_DNA_5_0  \
# Metadata_compound_name
# AX15836                                          0.143374
# BJP-06-005-3                                     0.022832
# BJP-06-115-3                                    -0.285641
# BSJ-03-136                                       0.355008
# BSJ-04-030                                       0.069513
#
#                         Nuclei_Texture_SumEntropy_RNA_5_0  \
# Metadata_compound_name
# AX15836                                          0.708184
# BJP-06-005-3                                     0.744384
# BJP-06-115-3                                     0.426432
# BSJ-03-136                                      -0.959514
# BSJ-04-030                                      -0.444151
#
#                         Nuclei_Texture_SumVariance_DNA_20_0  \
# Metadata_compound_name
# AX15836                                           -0.130434
# BJP-06-005-3                                      -0.201730
# BJP-06-115-3                                      -0.551706
# BSJ-03-136                                         1.008034
# BSJ-04-030                                         0.662521
#
#                         Nuclei_Texture_Variance_ER_20_0  \
# Metadata_compound_name
# AX15836                                        0.196846
# BJP-06-005-3                                  -0.336601
# BJP-06-115-3                                  -0.550827
# BSJ-03-136                                    -1.256256
# BSJ-04-030                                     0.367962
#
#                         Nuclei_Texture_Variance_Mito_20_0  \
# Metadata_compound_name
# AX15836                                         -0.176745
# BJP-06-005-3                                    -0.221760
# BJP-06-115-3                                    -0.737831
# BSJ-03-136                                       0.670170
# BSJ-04-030                                       0.888484
#
#                         Nuclei_Texture_Variance_RNA_10_0
# Metadata_compound_name
# AX15836                                         0.585618
# BJP-06-005-3                                    0.870045
# BJP-06-115-3                                    0.357346
# BSJ-03-136                                     -0.876329
# BSJ-04-030                                     -0.203274
#
# [5 rows x 598 columns]

# %% [markdown]
# # For combining merging two cell lines

# %%
Z_A549 =sch.linkage(df_A549_merge, 'ward')
fig = dendrogram(Z_A549, leaf_rotation=0, orientation="left", labels=df_A549_merge.index)
plt.savefig('/Users/habbasi/Desktop/Gray_dendogram_A549.pdf', bbox_inches='tight')

# %%
Z_U2oS =sch.linkage(df_U2oS_merge, 'ward')
fig = dendrogram(Z_U2oS, leaf_rotation=0, orientation="left", labels=df_U2oS_merge.index)
plt.savefig('/Users/habbasi/Desktop/Gray_dendogram_U2oS.pdf', bbox_inches='tight')

# %%
Z=sch.linkage(df_merge, 'ward')
fig = dendrogram(Z, leaf_rotation=0, orientation="left", labels=df_merge.index)
# my_palette = plt.cm.get_cmap("Accent", 3)
# test['Metadata_broad_sample'] = pd.Categorical(test['Metadata_broad_sample'])
plt.savefig('/Users/habbasi/Desktop/Gray_dendogram.pdf', bbox_inches='tight')

# %%
fig = sch.dendrogram(sch.linkage(df_merge, method ='ward'))
plt.title('Hierarchical Clustering Dendogram')
plt.xlabel('Compounds')
plt.ylabel('Eucledian Distance')
plt.axhline(y=60)
plt.savefig('/Users/habbasi/Desktop/Gray_dendogram_top.pdf', bbox_inches='tight')
