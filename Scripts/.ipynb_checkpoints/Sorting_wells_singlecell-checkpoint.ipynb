# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path

# %%
path = Path("../BR00100032/BR00100032_Metadata.csv")
prf = pd.read_csv(path)



# df['Metadata_Target'].replace(np.nan, 'NA', inplace=True)
# df['Metadata_Annotation'].replace('active ', 'active', inplace=True)

# dm = ['NA']

# dmso_wells = (df.query("Metadata_Target in @ dm")['Metadata_Well']
# .sample(n=16, random_state=1)
#               .tolist()
            
#              )
# sec = ['SECRET']

# secret = (df.query("Metadata_Target in @ sec")['Metadata_Well']
#               .tolist()
#          )
# secret

# selected_wells = dmso_wells+secret
# Out:
#   Metadata_broad_sample Metadata_Plate Metadata_Well  \
# 0                  DMSO     BR00100032           A01
# 1                  DMSO     BR00100032           A02
# 2                  DMSO     BR00100032           A03
# 3                  DMSO     BR00100032           A04
# 4                  DMSO     BR00100032           A05
#
#   Metadata_Assay_Plate_Barcode Metadata_Plate_Map_Name Metadata_cell_line  \
# 0                   BR00100032  C-7210-01-CMP-008-gray               A549
# 1                   BR00100032  C-7210-01-CMP-008-gray               A549
# 2                   BR00100032  C-7210-01-CMP-008-gray               A549
# 3                   BR00100032  C-7210-01-CMP-008-gray               A549
# 4                   BR00100032  C-7210-01-CMP-008-gray               A549
#
#   Metadata_well_position  Metadata_mg_per_ml  Metadata_mmoles_per_liter  \
# 0                    A01                 0.0                        0.0
# 1                    A02                 0.0                        0.0
# 2                    A03                 0.0                        0.0
# 3                    A04                 0.0                        0.0
# 4                    A05                 0.0                        0.0
#
#   Metadata_solvent  ... Metadata_pert_id_vendor Metadata_broad_sample_type  \
# 0             DMSO  ...                     NaN                    control
# 1             DMSO  ...                     NaN                    control
# 2             DMSO  ...                     NaN                    control
# 3             DMSO  ...                     NaN                    control
# 4             DMSO  ...                     NaN                    control
#
#   Metadata_pert_vehicle Metadata_pert_type  Metadata_label  Metadata_chemist  \
# 0                  DMSO            control            DMSO  Drug Repurposing
# 1                  DMSO            control            DMSO  Drug Repurposing
# 2                  DMSO            control            DMSO  Drug Repurposing
# 3                  DMSO            control            DMSO  Drug Repurposing
# 4                  DMSO            control            DMSO  Drug Repurposing
#
#   Metadata_compound_name Metadata_Annotation Metadata_Target  \
# 0                   DMSO             control             NaN
# 1                   DMSO             control             NaN
# 2                   DMSO             control             NaN
# 3                   DMSO             control             NaN
# 4                   DMSO             control             NaN
#
#   Metadata_Broad_barcode
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 24 columns]

# %%
path = Path("../BR00100037/BR00100037_Metadata.csv")
prf = pd.read_csv(fpath)

prf['Metadata_Target'].replace(np.nan, 'NA', inplace=True)
prf['Metadata_Annotation'].replace('active ', 'active', inplace=True)

moa = ['NA']

dmso_wells = (prf.query("Metadata_Target in @ moa")['Metadata_Well']
.sample(n=16, random_state=1)
              .tolist()
             )
moa= ['SECRET']

secret = (df.query("Metadata_Target in @ moa")['Metadata_Well']
              .tolist()
         )
secret
# Out:
# ['H05',
#  'H09',
#  'I03',
#  'I16',
#  'H18',
#  'I20',
#  'H22',
#  'I07',
#  'G22',
#  'G09',
#  'J03',
#  'J07',
#  'G18',
#  'J16',
#  'G05',
#  'J20']
